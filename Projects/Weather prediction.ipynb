# %% [markdown]
# WEATHER PREDICTION

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %% [markdown]
# LOAD DATASET

# %%
df=pd.read_csv("D:\Data Science With Python\dataset\Weather Test Data (1).csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\dines\AppData\Local\Temp\ipykernel_15348\1706280281.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("D:\Data Science With Python\dataset\Weather Test Data (1).csv")

# %% [markdown]
# FEATURE ENGINEERING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42677 entries, 0 to 42676
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row ID         42677 non-null  object
#  1   Location       42677 non-null  object
#  2   MinTemp        42483 non-null  float64
#  3   MaxTemp        42585 non-null  float64
#  4   Rainfall       42250 non-null  float64
#  5   Evaporation    24365 non-null  float64
#  6   Sunshine       22178 non-null  float64
#  7   WindGustDir    39868 non-null  object
#  8   WindGustSpeed  39887 non-null  float64
#  9   WindDir9am     39670 non-null  object
#  10  WindDir3pm     41547 non-null  object
#  11  WindSpeed9am   42264 non-null  float64
#  12  WindSpeed3pm   41882 non-null  float64
#  13  Humidity9am    42136 non-null  float64
#  14  Humidity3pm    41573 non-null  float64
#  15  Pressure9am    38411 non-null  float64
#  16  Pressure3pm    38432 non-null  float64
# ...

# %%
df.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  42483.000000  42585.000000  42250.000000  24365.000000  22178.000000
# mean      12.210032     23.246068      2.342862      5.489715      7.647831
# std        6.432122      7.123596      8.412106      4.248850      3.778019
# min       -8.200000     -4.800000      0.000000      0.000000      0.000000
# 25%        7.600000     18.000000      0.000000      2.600000      4.900000
# 50%       12.000000     22.600000      0.000000      4.800000      8.500000
# 75%       16.900000     28.300000      0.600000      7.400000     10.700000
# max       31.800000     47.000000    278.400000    145.000000     14.300000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   39887.000000  42264.000000  41882.000000  42136.000000  41573.000000
# mean       40.001379     13.995315     18.607516     68.791176     51.597672
# ...

# %%
df.isnull().sum()
# Out:
# row ID               0
# Location             0
# MinTemp            194
# MaxTemp             92
# Rainfall           427
# Evaporation      18312
# Sunshine         20499
# WindGustDir       2809
# WindGustSpeed     2790
# WindDir9am        3007
# WindDir3pm        1130
# WindSpeed9am       413
# WindSpeed3pm       795
# Humidity9am        541
# Humidity3pm       1104
# Pressure9am       4266
# Pressure3pm       4245
# Cloud9am         16085
# Cloud3pm         17092
# Temp9am            290
# Temp3pm            822
# RainToday          427
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(95340)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42677 entries, 0 to 42676
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row ID         42677 non-null  object
#  1   Location       42677 non-null  object
#  2   MinTemp        42483 non-null  float64
#  3   MaxTemp        42585 non-null  float64
#  4   Rainfall       42250 non-null  float64
#  5   Evaporation    24365 non-null  float64
#  6   Sunshine       22178 non-null  float64
#  7   WindGustDir    39868 non-null  object
#  8   WindGustSpeed  39887 non-null  float64
#  9   WindDir9am     39670 non-null  object
#  10  WindDir3pm     41547 non-null  object
#  11  WindSpeed9am   42264 non-null  float64
#  12  WindSpeed3pm   41882 non-null  float64
#  13  Humidity9am    42136 non-null  float64
#  14  Humidity3pm    41573 non-null  float64
#  15  Pressure9am    38411 non-null  float64
#  16  Pressure3pm    38432 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['row ID']=le.fit_transform(df['row ID'])
df['Location']=le.fit_transform(df['Location'])
df['WindGustDir']=le.fit_transform(df['WindGustDir'])
df['WindDir9am']=le.fit_transform(df['WindDir9am'])
df['WindDir3pm']=le.fit_transform(df['WindDir3pm'])
df['RainToday']=le.fit_transform(df['RainToday'])
df
# Out:
#        row ID  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0           0         2     12.9     25.7       0.0          NaN       NaN
# 1           1         2      9.2     28.0       0.0          NaN       NaN
# 2       10859         2     14.3     25.0       0.0          NaN       NaN
# 3       21632         2      9.7     31.9       0.0          NaN       NaN
# 4       32544         2     15.9     18.6      15.6          NaN       NaN
# ...       ...       ...      ...      ...       ...          ...       ...
# 42672   36506        41      2.4     19.1       0.0          NaN       NaN
# 42673   36507        41      2.3     21.4       0.0          NaN       NaN
# 42674   36508        41      2.6     22.5       0.0          NaN       NaN
# 42675   36509        41      7.4     20.6       0.0          NaN       NaN
# 42676   36510        41      7.8     27.0       0.0          NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42677 entries, 0 to 42676
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row ID         42677 non-null  int64
#  1   Location       42677 non-null  int64
#  2   MinTemp        42483 non-null  float64
#  3   MaxTemp        42585 non-null  float64
#  4   Rainfall       42250 non-null  float64
#  5   Evaporation    24365 non-null  float64
#  6   Sunshine       22178 non-null  float64
#  7   WindGustDir    42677 non-null  int64
#  8   WindGustSpeed  39887 non-null  float64
#  9   WindDir9am     42677 non-null  int64
#  10  WindDir3pm     42677 non-null  int64
#  11  WindSpeed9am   42264 non-null  float64
#  12  WindSpeed3pm   41882 non-null  float64
#  13  Humidity9am    42136 non-null  float64
#  14  Humidity3pm    41573 non-null  float64
#  15  Pressure9am    38411 non-null  float64
#  16  Pressure3pm    38432 non-null  float64
# ...

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#              row ID      Location       MinTemp       MaxTemp      Rainfall  \
# count  42677.000000  42677.000000  42483.000000  42585.000000  42250.000000
# mean   21338.000000     23.718045     12.210032     23.246068      2.342862
# std    12319.933056     14.263988      6.432122      7.123596      8.412106
# min        0.000000      0.000000     -8.200000     -4.800000      0.000000
# 25%    10669.000000     11.000000      7.600000     18.000000      0.000000
# 50%    21338.000000     24.000000     12.000000     22.600000      0.000000
# 75%    32007.000000     36.000000     16.900000     28.300000      0.600000
# max    42676.000000     48.000000     31.800000     47.000000    278.400000
#
#         Evaporation      Sunshine   WindGustDir  WindGustSpeed    WindDir9am  \
# count  24365.000000  22178.000000  42677.000000   39887.000000  42677.000000
# mean       5.489715      7.647831      8.255383      40.001379      7.931485
# ...

# %%
df.isnull().sum()
df.head(8)
# Out:
#    row ID  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       0         2     12.9     25.7       0.0          NaN       NaN
# 1       1         2      9.2     28.0       0.0          NaN       NaN
# 2   10859         2     14.3     25.0       0.0          NaN       NaN
# 3   21632         2      9.7     31.9       0.0          NaN       NaN
# 4   32544         2     15.9     18.6      15.6          NaN       NaN
# 5   38293         2     11.5     29.3       0.0          NaN       NaN
# 6   39400         2     16.2     33.9       0.0          NaN       NaN
# 7   40479         2     12.0     24.4       0.8          NaN       NaN
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  WindSpeed3pm  Humidity9am  \
# 0           15           46.0          13  ...          26.0         38.0
# 1            4           24.0           9  ...           9.0         45.0
# 2           13           50.0          12  ...          24.0         49.0
# ...

# %%
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].median())
df['WindSpeed9am']=df['WindSpeed9am'].fillna(df['WindSpeed9am'].median())
df['WindSpeed3pm']=df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].median())
df['Humidity9am']=df['Humidity9am'].fillna(df['Humidity9am'].median())
df['Humidity3pm']=df['Humidity3pm'].fillna(df['Humidity3pm'].median())
df['Pressure9am']=df['Pressure9am'].fillna(df['Pressure9am'].median())
df['Pressure3pm']=df['Pressure3pm'].fillna(df['Pressure3pm'].median())
df['Cloud9am']=df['Cloud9am'].fillna(df['Cloud9am'].median())
df['Cloud3pm']=df['Cloud3pm'].fillna(df['Cloud3pm'].median())
df['Temp9am']=df['Temp9am'].fillna(df['Temp9am'].median())
df['Temp3pm']=df['Temp3pm'].fillna(df['Temp3pm'].median())
df['RainToday']=df['RainToday'].fillna(df['RainToday'].median())
df.isnull().sum()
df.isnull().sum()
# Out:
# row ID               0
# Location             0
# MinTemp            194
# MaxTemp             92
# Rainfall           427
# Evaporation      18312
# Sunshine         20499
# WindGustDir          0
# WindGustSpeed        0
# WindDir9am           0
# WindDir3pm           0
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday            0
# dtype: int64

# %%
df.head(8)
# Out:
#    row ID  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       0         2     12.9     25.7       0.0          NaN       NaN
# 1       1         2      9.2     28.0       0.0          NaN       NaN
# 2   10859         2     14.3     25.0       0.0          NaN       NaN
# 3   21632         2      9.7     31.9       0.0          NaN       NaN
# 4   32544         2     15.9     18.6      15.6          NaN       NaN
# 5   38293         2     11.5     29.3       0.0          NaN       NaN
# 6   39400         2     16.2     33.9       0.0          NaN       NaN
# 7   40479         2     12.0     24.4       0.8          NaN       NaN
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  WindSpeed3pm  Humidity9am  \
# 0           15           46.0          13  ...          26.0         38.0
# 1            4           24.0           9  ...           9.0         45.0
# 2           13           50.0          12  ...          24.0         49.0
# ...

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# row ID           0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# dtype: int64

# %%
import numpy as np
df.replace('78',np.nan,inplace=True)
df.dropna(inplace=True)

# %%
x=df.drop(['RainToday','Location'],axis=1)
y=df['RainToday']
x
# Out:
#        row ID  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 1756     8497     18.4     28.9       0.0         14.8      13.0            8
# 1757     8508     19.4     37.6       0.0         10.8      10.6            5
# 1758     8519     21.9     38.4       0.0         11.4      12.2           14
# 1759     8531     24.2     41.0       0.0         11.2       8.4           14
# 1760     8542     19.7     35.5       0.0         11.0      12.7            4
# ...       ...      ...      ...       ...          ...       ...          ...
# 41697   35436     17.2     29.1       0.0          7.2      10.1            2
# 41698   35437     18.3     29.8       0.0          8.4      10.5            2
# 41699   35438     16.9     30.3       0.0          5.4      10.9            0
# 41700   35439     20.2     32.1       0.0          4.8       9.9            0
# 41701   35441     19.5     31.8       0.0          6.2      10.6            2
#
# ...

# %%
y
# Out:
# 1756     0
# 1757     0
# 1758     0
# 1759     0
# 1760     0
#         ..
# 41697    0
# 41698    0
# 41699    0
# 41700    0
# 41701    0
# Name: RainToday, Length: 20912, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df.shape
# Out:
# (20912, 22)

# %% [markdown]
# USING MINMAX SCALER FOR NORMALISATION

# %%
from sklearn.preprocessing import MinMaxScaler  
mm=MinMaxScaler()
x=mm.fit_transform(x)
x
# Out:
# array([[0.19901104, 0.64643799, 0.58628842, ..., 0.125     , 0.52369077,
#         0.558753  ],
#        [0.19926882, 0.67282322, 0.79196217, ..., 0.75      , 0.73316708,
#         0.74820144],
#        [0.19952661, 0.73878628, 0.8108747 , ..., 0.625     , 0.74314214,
#         0.76498801],
#        ...,
#        [0.8303766 , 0.60686016, 0.61938534, ..., 0.        , 0.56109726,
#         0.59952038],
#        [0.83040004, 0.6939314 , 0.66193853, ..., 0.375     , 0.61346633,
#         0.65947242],
#        [0.83044691, 0.67546174, 0.65484634, ..., 0.125     , 0.63591022,
#         0.61151079]], shape=(20912, 20))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)                            #this is for train (minimaxscaler)
y_pred=model.predict(x_test)
print(y_pred)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# [0 1 0 ... 0 0 1]
# 0.8876404494382022
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3291
#            1       0.89      0.54      0.67       892
#
#     accuracy                           0.89      4183
#    macro avg       0.89      0.76      0.80      4183
# weighted avg       0.89      0.89      0.88      4183
#
# [[3228   63]
#  [ 407  485]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_test,y_test)
y_pred=model.predict(x_test)                               #this is for test (minimaxscaler)
print(y_pred)
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [0 1 0 ... 0 0 1]
# [[3197   94]
#  [ 481  411]]
# 0.8625388477169496
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      3291
#            1       0.81      0.46      0.59       892
#
#     accuracy                           0.86      4183
#    macro avg       0.84      0.72      0.75      4183
# weighted avg       0.86      0.86      0.85      4183

# %% [markdown]
# IT IS A GENERALISED FIT
